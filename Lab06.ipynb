# %% [markdown]
# <a href="https://colab.research.google.com/github/NelliRishitha/DATA-MINING/blob/main/Lab06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
#example data
data={'category':['A','B','C','A','B']}
df=pd.DataFrame(data)
df
# Out:
#   category
# 0        A
# 1        B
# 2        C
# 3        A
# 4        B

# %%
#label encoding
label_encoder=LabelEncoder()
df['Label_Encoder']=label_encoder.fit_transform(df['category'])
df
# Out:
#   category  Label_Encoder  category_A  category_B  category_C  category_A  \
# 0        A              0         NaN         NaN         NaN        True
# 1        B              1         NaN         NaN         NaN       False
# 2        C              2         NaN         NaN         NaN       False
# 3        A              0         NaN         NaN         NaN        True
# 4        B              1         NaN         NaN         NaN       False
# 0      NaN              3        True       False       False       False
# 1      NaN              3       False        True       False       False
# 2      NaN              3       False       False        True       False
# 3      NaN              3        True       False       False       False
# 4      NaN              3       False        True       False       False
#
#    category_B  category_C
# 0       False       False
# 1        True       False
# 2       False        True
# 3       False       False
# ...

# %%
#one hot encoding
one_hot_encoder=pd.get_dummies(df['category'],prefix='category')
df=pd.concat([df,one_hot_encoder],axis=1)
df
# Out:
#   category  Label_Encoder  category_A  category_B  category_C  category_A  \
# 0        A            0.0         NaN         NaN         NaN        True
# 1        B            1.0         NaN         NaN         NaN       False
# 2        C            2.0         NaN         NaN         NaN       False
# 3        A            0.0         NaN         NaN         NaN        True
# 4        B            1.0         NaN         NaN         NaN       False
# 0      NaN            NaN        True       False       False       False
# 1      NaN            NaN       False        True       False       False
# 2      NaN            NaN       False       False        True       False
# 3      NaN            NaN        True       False       False       False
# 4      NaN            NaN       False        True       False       False
#
#    category_B  category_C
# 0       False       False
# 1        True       False
# 2       False        True
# 3       False       False
# ...

# %%
#example data
data={'Name ':['Alice','Bob'],'Date_of_Birth':['1990-05-14','1995-08-23']}
data=pd.DataFrame(data)
df
# Out:
#    Name  Date_of_Birth  Age
# 0  Alice    1990-05-14   35
# 1    Bob    1995-08-23   30

# %%
#convert date_of_birth to datatime
df['Date_of_Birth']=pd.to_datetime(df['Date_of_Birth'])
df
# Out:
#    Name  Date_of_Birth
# 0  Alice    1990-05-14
# 1    Bob    1995-08-23

# %%
# Import the datetime module
from datetime import datetime

#calculate age
current_year=datetime.now().year
df['Age']=current_year-df['Date_of_Birth'].dt.year

# %%
print(df)
# Out:
#    Name  Date_of_Birth  Age
# 0  Alice    1990-05-14   35
# 1    Bob    1995-08-23   30

# %%
#example data
data={'category':['A','B','C','A','B'],
      'Value':[10,20,10,30,40]}
df=pd.DataFrame(data)
df
# Out:
#   category  Value
# 0        A     10
# 1        B     20
# 2        C     10
# 3        A     30
# 4        B     40

# %%
#Group by and aggregate
grouped = df.groupby('category')['Value'].agg(['sum', 'mean'])
df
# Out:
#   category  Value
# 0        A     10
# 1        B     20
# 2        C     10
# 3        A     30
# 4        B     40

# %%
#pivot table
pivot=df.pivot_table(index='category',values='Value',aggfunc=['sum','mean'])
print("\nPivot Table\n",pivot)
# Out:
# Pivot Table
#             sum  mean
#          Value Value
# category
# A           40  20.0
# B           60  30.0
# C           10  10.0
