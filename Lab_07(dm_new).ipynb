# %% [markdown]
# <a href="https://colab.research.google.com/github/NelliRishitha/DATA-MINING/blob/main/Lab_07(dm_new).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Add noise to the data
noise = np.random.normal(0, 5, X.shape[0])  # Adjust noise level to see impact
y = y_true + noise  # Noisy observations

# %%
# Fit a simple linear regression model
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# %%
# Plot the data
plt.scatter(X, y, label='Noisy Data')
plt.plot(X, y_true, label='True Relationship', linestyle='dashed', color='green')
plt.plot(X, y_pred, label='Regression Line', color='red')
plt.legend()
plt.xlabel('X')
plt.ylabel('y')
plt.title('Simple Linear Regression')
plt.show()

# %%
# Print model parameters
print(f'Intercept: {model.intercept_}')
print(f'Coefficient: {model.coef_[0]}')
print(f'Mean Squared Error: {mean_squared_error(y, y_pred)}')
# Out:
# Intercept: 7.322215461014862
# Coefficient: 2.710083002540888
# Mean Squared Error: 20.628544877778936

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model
